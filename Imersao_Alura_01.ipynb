# %% [markdown]
# <a href="https://colab.research.google.com/github/Luizgs7/Imersao_Dados_Bioestatistica/blob/main/Imersao_Alura_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula 01

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

# %%
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=True'

dados = pd.read_csv(url_dados, compression='zip')
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
# Renomeando colunas: tirando hífen do nome das colunas

# Cria dicionário com o antigo nome e o novo nome (substituindo o hífen por underline)
columns = dict(zip(dados.columns, dados.columns.str.replace('-', '_')))

# Renomeia na base original
dados.rename(columns = columns, inplace = True)
dados.head()
# Out:
#              id tratamento  tempo dose      droga     g_0     g_1     g_2  \
# 0  id_000644bb2  com_droga     24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  com_droga     72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  com_droga     48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 3  id_0015fd391  com_droga     48   D1  8c7f86626 -0.5138 -0.2491 -0.2656
# 4  id_001626bd3  com_droga     72   D2  7cbed3131 -0.3254 -0.4009  0.9700
#
#       g_3     g_4     g_5     g_6     g_7     g_8     g_9    g_10    g_11  \
# 0 -0.6208 -0.1944 -1.0120 -1.0220 -0.0326  0.5548 -0.0921  1.1830  0.1530
# 1  0.0604  1.0190  0.5207  0.2341  0.3372 -0.4047  0.8507 -1.1520 -0.4201
# 2 -0.0764 -0.0323  1.2390  0.1715  0.2155  0.0065  1.2300 -0.4797 -0.5631
# 3  0.5288  4.0620 -0.8095 -1.9590  0.1792 -0.1321 -1.0600 -0.8269 -0.3584
# 4  0.6919  1.4180 -0.8244 -0.2800 -0.1498 -0.8789  0.8630 -0.2219 -0.5121
#
# ...

# %%
dados.shape
# Out:
# (23814, 877)

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['tratamento'].value_counts(normalize=True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['tempo'].value_counts(normalize=True).plot.bar()

# %%
dados['tratamento'].value_counts(normalize=True).plot.bar(rot=0, color={'green':'com_droga', 'red': 'com_controle'})

# %%
dados[dados['g-0']>0]
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6      id_001bd861f     com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23807  id_fff7e6992     com_droga     48   D1  ...  0.3738  0.8636  0.4494  0.1218
# 23808  id_fff8c2444     com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %% [markdown]
# ### Desafios
# 1 - Investigar porque a classe tratamento é tão desbalanceada?
#
# 2 - Plotar as últimas 5 linhas da tabela
#
# 3 - Calcular a proporção das classes de tratamentos
#
# 4 - Quantos tipos de drogas investigadas?
#
# 5 - Procurar na documentação o método query(pandas)
#
# 6 - Título no gráfico
#
# 7 - Renomear colunas tirando o hifen
#
# 8 - Resumo do que aprendemos com os dados

# %%
# 1 - Investigar porque a classe tratamento é tão desbalanceada?

# %%
# 2 - Plotar as últimas 5 linhas da tabela 
dados.tail()

# %%
# 3 - Calcular a proporção das classes de tratamentos
dados['tratamento'].value_counts(normalize=True)

# %%
# 4 - Quantos tipos de drogas investigadas?
len(dados['droga'].unique())

# %%
# 5 - Procurar na documentação o método query(pandas)
dados.query('g_0 > 0')

# %%
# 6 - Título no gráfico
dados['tempo'].value_counts(normalize=True).plot(kind = 'bar', 
                                                 title = 'Proporção das amostras por período de tempo',
                                                 ylabel = 'Proporção',
                                                 xlabel = 'Período de tempo',
                                                 sort_columns=True)

# %%
# 7 - Renomear colunas tirando o hifen
# Cria dicionário com o antigo nome e o novo nome (substituindo o hífen por underline)
columns = dict(zip(dados.columns, dados.columns.str.replace('-', '_')))

# Renomeia na base original
dados.rename(columns = columns, inplace = True)
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c_96    c_97    c_98    c_99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
# 8 - Resumo do que aprendemos com os dados
# Aprendemos que a tabela a ser analisada possui mais de 20K registros, com 770 genes do tipo 'g' e 98 do tipo 'c'
# Além disso, conseguimos entender as proporções das variáveis categóricas (tratamento, tepo, dose e droga) graficamente
